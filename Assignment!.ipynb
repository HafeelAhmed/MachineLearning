# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests as rq

# %%
url ="https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
request = rq.get(url)
request
# Out:
# <Response [200]>

# %%
html = bs(request.text)

# %%
titles = html.select("._4rR01T")
price = html.select("._1_WHN1")
description = html.select(".fMghEO")
offerPercentage= html.select("._3tbKJL span")

# %%
laptopDetails = pd.DataFrame(Titles,columns=["Laptop Name"])
laptopDetails["Price"] = price
laptopDetails["Offer %"] = offerPercentage
laptopDetails["Description"] = description

# %%
laptopDetails
# Out:
#                                           Laptop Name        Price    Offer %  \
# 0   Primebook 4G enabled Android based MediaTek MT...    [₹14,990]  [46% off]
# 1   Lenovo LOQ Ryzen 7 Octa Core 7840HS - (16 GB/5...    [₹99,990]  [25% off]
# 2   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...    [₹34,990]  [30% off]
# 3   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...    [₹42,990]  [38% off]
# 4   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...    [₹35,990]  [43% off]
# 5   HP 15s (2023) Athlon Dual Core 3050U - (8 GB/5...    [₹31,990]   [8% off]
# 6   HP 15s (2023) Intel Core i5 11th Gen - (16 GB/...    [₹52,990]  [10% off]
# 7   Primebook 4G Android Based MediaTek MT8788 - (...    [₹13,990]  [44% off]
# 8   HP 15s (2023) Intel Core i3 12th Gen - (8 GB/5...    [₹39,990]  [21% off]
# 9   Acer One Core i3 11th Gen - (8 GB/256 GB SSD/W...    [₹26,990]  [35% off]
# 10  Lenovo LOQ Ryzen 7 Octa Core 7840HS - (16 GB/5...    [₹87,550]  [25% off]
# 11  Lenovo LOQ Core i7 13th Gen - (16 GB/512 GB SS...  [₹1,14,990]  [25% off]
# 12  realme Book (Slim) Core i3 11th Gen - (8 GB/25...    [₹36,999]  [32% off]
# 13  HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...    [₹40,999]  [17% off]
# 14  Lenovo IdeaPad Gaming 3 Intel Core i5 11th Gen...    [₹48,990]  [30% off]
# 15  Lenovo V15 Ryzen 5 Hexa Core 5500U - (8 GB/512...    [₹35,990]  [48% off]
# 16  ASUS Vivobook Pro 15 For Creator, Ryzen 5 Hexa...    [₹54,990]  [28% off]
# 17  Primebook 4G Android Based MediaTek MT8788 - (...    [₹14,990]  [46% off]
# 18  Acer Extensa (2023) Core i3 - (8 GB/256 GB SSD...    [₹30,990]  [31% off]
# 19  ASUS Vivobook 15 Core i3 11th Gen - (8 GB/256 ...    [₹32,990]  [26% off]
# 20  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...    [₹40,490]  [40% off]
# 21  MSI Ryzen 5 Hexa Core 7530U - (8 GB/512 GB SSD...    [₹39,990]  [35% off]
# 22  Lenovo IdeaPad 1 Celeron Dual Core - (8 GB/256...    [₹25,990]  [32% off]
# 23  HP Intel Core i5 11th Gen - (8 GB/512 GB SSD/W...    [₹52,990]   [6% off]
#
#                                           Description
# 0   [[[MediaTek MediaTek MT8788 Processor], [4 GB ...
# 1   [[[AMD Ryzen 7 Octa Core Processor], [16 GB DD...
# 2   [[[Intel Core i3 Processor (11th Gen)], [8 GB ...
# 3   [[[Intel Core i5 Processor (11th Gen)], [8 GB ...
# 4   [[[Intel Core i3 Processor (11th Gen)], [8 GB ...
# 5   [[[AMD Athlon Dual Core Processor], [8 GB DDR4...
# 6   [[[Intel Core i5 Processor (11th Gen)], [16 GB...
# 7   [[[MediaTek MediaTek MT8788 Processor], [4 GB ...
# 8   [[[Intel Core i3 Processor (12th Gen)], [8 GB ...
# 9   [[[Intel Core i3 Processor (11th Gen)], [8 GB ...
# 10  [[[AMD Ryzen 7 Octa Core Processor], [16 GB DD...
# 11  [[[Intel Core i7 Processor (13th Gen)], [16 GB...
# 12  [[[Stylish & Portable Thin and Light Laptop], ...
# 13  [[[AMD Ryzen 5 Hexa Core Processor], [8 GB DDR...
# 14  [[[Intel Core i5 Processor (11th Gen)], [8 GB ...
# 15  [[[AMD Ryzen 5 Hexa Core Processor], [8 GB DDR...
# 16  [[[AMD Ryzen 5 Hexa Core Processor], [8 GB DDR...
# 17  [[[MediaTek MediaTek MT8788 Processor], [4 GB ...
# 18  [[[Intel Core i3 Processor], [8 GB LPDDR5 RAM]...
# 19  [[[Intel Core i3 Processor (11th Gen)], [8 GB ...
# 20  [[[AMD Ryzen 5 Hexa Core Processor], [8 GB DDR...
# 21  [[[AMD Ryzen 5 Hexa Core Processor], [8 GB DDR...
# 22  [[[Intel Celeron Dual Core Processor], [8 GB D...
# 23  [[[Intel Core i5 Processor (11th Gen)], [8 GB ...
